# %%
import pandas as pd
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang   oldpeak  \
# 0   67    0   3       195   236    0        1      179      1  3.901276
# 1   57    1   1       126   232    0        0      108      0  0.706140
# 2   43    0   3        96   288    0        2       62      1  0.059875
# 3   71    1   2        94   376    1        0      106      0  4.168085
# 4   36    0   0       168   324    0        2       76      0  4.293673
#
#    slope  ca  thal  target
# 0      2   3     2       1
# 1      1   3     2       1
# 2      1   1     3       1
# 3      0   2     1       0
# 4      1   2     3       1

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler=MinMaxScaler()
x=np.array(df.drop('target', axis='columns'))
print(x)
model=scaler.fit(x)
x_sc=model.transform(x)
x_sc
# Out:
# [[67.  0.  3. ...  2.  3.  2.]
#  [57.  1.  1. ...  1.  3.  2.]
#  [43.  0.  3. ...  1.  1.  3.]
#  ...
#  [41.  0.  0. ...  1.  3.  1.]
#  [65.  0.  2. ...  2.  1.  3.]
#  [48.  0.  0. ...  1.  3.  3.]]
# array([[0.79166667, 0.        , 1.        , ..., 1.        , 1.        ,
#         0.5       ],
#        [0.58333333, 1.        , 0.33333333, ..., 0.5       , 1.        ,
#         0.5       ],
#        [0.29166667, 0.        , 1.        , ..., 0.5       , 0.33333333,
#         1.        ],
#        ...,
#        [0.25      , 0.        , 0.        , ..., 0.5       , 1.        ,
#         0.        ],
#        [0.75      , 0.        , 0.66666667, ..., 1.        , 0.33333333,
#         1.        ],
#        [0.39583333, 0.        , 0.        , ..., 0.5       , 1.        ,
#         1.        ]])

# %%
y=np.array(df.target)
y
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df.drop(['target', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs'], axis='columns'))

# %%
sns.pairplot(df.drop(['thal', 'ca', 'slope', 'oldpeak', 'exang', 'thalach'], axis='columns'))

# %%
dataplot = sns.heatmap(df.drop(['target', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs'], axis='columns').corr(numeric_only=True), cmap="YlGnBu", annot=True)
plt.show()

# %%
dataplot = sns.heatmap(df.drop(['target', 'thal', 'ca', 'slope', 'oldpeak', 'exang', 'thalach'], axis='columns').corr(numeric_only=True), cmap="YlGnBu", annot=True)
plt.show()
